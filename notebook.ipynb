# %% [markdown]
# ## Working With JSON In PostgreSQL

# %%
# install dependencies

# !uv pip install jupysql psycopg2-binary pandas matplotlib sqlalchemy --quiet

import warnings
warnings.filterwarnings("ignore", category=SyntaxWarning, module="sql.parse")

# load sql extension
# %load_ext sql
# %config SqlMagic.displaylimit = 10 
# %config SqlMagic.autopandas = True
# %config SqlMagic.displaycon = False
# %config SqlMagic.feedback = False
# %sql postgresql+psycopg2://hones:secretpassword@localhost:9876/marketplace
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT count(*) FROM products
# Out:
#     count
# 0  100000
